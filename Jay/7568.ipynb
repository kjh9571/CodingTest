# %%
n = int(input())

list = []
for i in range(n):
    w, h = map(int, input().split())
    list.append((w, h)) 
for i in range(n):
    count = 1
    for j in range(n):
        if list[i][0] < list[j][0] and list[i][1] < list[j][1]:
            count += 1 
    print(count, end=' ')
# Out:
# 3
# 55 185
# 88 186
# 46 155
# 2 2 3
